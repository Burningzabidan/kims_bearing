# %% [markdown]
# <a href="https://colab.research.google.com/github/Burningzabidan/kims_bearing/blob/main/%5B%E1%84%87%E1%85%A6%E1%84%8B%E1%85%A5%E1%84%85%E1%85%B5%E1%86%BC%E1%84%80%E1%85%AA%E1%84%8C%E1%85%A6%5D%E1%84%80%E1%85%A1%E1%86%BC%E1%84%83%E1%85%A9_%E1%84%8B%E1%85%A8%E1%84%8E%E1%85%B3%E1%86%A8_v0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision import models
from torchvision import transforms

import os
import cv2
from PIL import Image
import re
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# #1. 인장 시험 데이터 가져오기 및 정리

# %%
def pre_proc(file_dir:str) -> pd.DataFrame:
    """
    인장 시험 파일 불러오기
    불필요한 문자 삭제
    파일 df화
    """
    # load tensile test result
    f = open(file_dir,"r")
    lines = f.readlines()
    new_lines = []

    # \n, 공백 삭제
    for line in lines:
      new_lines.append(re.sub('[\n| ]', '', line))

    # df로 만들기
    new_lines_np = np.array(new_lines).reshape(-1,6)
    tensile_res = [[] for _ in range(4)]
    for i in range(len(new_lines_np)):
      for j in new_lines_np[i]:
        if re.match('[가-힣]',j):
          if tensile_res[i%4] == []:
            tensile_res[i%4].append(j)
        else:
          tensile_res[i%4].append(j)

    tensile_res = np.array(tensile_res).reshape(4,-1)
    df_tensile_res = pd.DataFrame(tensile_res[1:,1:], index = tensile_res[1:,0])
    df_tensile_res.columns = tensile_res[0,1:]
    df_tensile_res
    return df_tensile_res

df_tensile_res = pre_proc("./properties/tensile_test_result.txt")
# check the result
df_tensile_res
# Out:
#                         1-1   1-2   1-3   1-4   1-5   2-1   2-2   2-3   2-4  \
# 인장강도N/mm2              1527  1439  1445  1421  1429  1200  1225  1256  1211
# 항복강도(0.2%offset)N/mm2  1454  1359  1381  1354  1369  1113  1128  1186  1117
# 연신율(GL:50mm)%            11    13    12    13    13    14    14    14    15
#
#                         2-5  ...   4-1   4-2   4-3   4-4  4-5  5-1  5-2  5-3  \
# 인장강도N/mm2              1253  ...  1004  1004  1033  1019  994  896  882  918
# 항복강도(0.2%offset)N/mm2  1170  ...   907   902   927   916  896  816  780  826
# 연신율(GL:50mm)%            15  ...    19    18    16    18   19   21   21   21
#
#                        5-4  5-5
# 인장강도N/mm2              897  928
# 항복강도(0.2%offset)N/mm2  831  845
# 연신율(GL:50mm)%           21   20
#
# [3 rows x 25 columns]

# %%
def get_linked_prop(df:pd.DataFrame) -> dict:
  """
  df로 정리된 인장 시험 결과를 샘플 시리즈를 keyword로,
  물성 별 측정값을 value로 갖는 딕셔너리를 반환함
  """
  # 빈 연결 리스트 생성
  properties = {}
  for i in range(1,6):
    properties[i] = {}
    for j in ("TS", "YS", "EL"):
      properties[i][j] = []

  # df로부터 시리즈별 물성을 연결 리스트에 저장
  for m in df_tensile_res.columns:
    for k,l in enumerate(["TS", "YS", "EL"]):
      p = int(df_tensile_res[m][k])
      properties[int(m[0])][l].append(p)
  return properties

properties = get_linked_prop(df_tensile_res)
# check the result
print(f"sample series:{list(properties.keys())}")
print(f"properties of each series:{list(properties[1].keys())}")
len_TS = len(properties[1]["TS"])
print(f"number of TS data:{len_TS}")
# Out:
# sample series:[1, 2, 3, 4, 5]
# properties of each series:['TS', 'YS', 'EL']
# number of TS data:5

# %% [markdown]
# #2. 이미지 데이터 가져오기 및 정리

# %%
### 연결 리스트로 샘플 시리즈별 이미지 정리

def get_lined_img(files_dir:str) -> dict:
  """
  이미지를 불러와서 샘플 시리즈를 keyword,
  이미지를 value로 갖는 딕셔너리를 반환함
  """
  # 빈 연결 리스트 생성
  imgs = {}
  for i in range(1,6):
    imgs[i] = []

  # 이미지를 크롭하여 시리즈별로 연결 리스트에 저장
  files = [f for f in os.listdir(files_dir) if "tif" in f]
  for file in files:
    img = (cv2.imread(files_dir+file)/255).astype(np.float32)
    h,w,c = img.shape
    for dx in range(0,h-448,56):
      for dy in range(0,w-448,56):
        img_crop = img[dx:dx+448,dy:dy+448]
        series = int(file[0])
        imgs[series].append(img_crop)

  return imgs

imgs = get_lined_img("./images/")

# check the result
print(f"number of sample series:{len(imgs)}")
print(f"number of sample subseries:{len(imgs[1])}")
print(f"size of images:{imgs[1][0].shape}")

# plot example
plt.figure(figsize = (4,4))
plt.imshow(imgs[1][0])
# Out:
# number of sample series:5
# number of sample subseries:150
# size of images:(448, 448, 3)

# %% [markdown]
# # 3. 이미지 별 물성 생성

# %%
### 연결 리스트로 생성된 물성 저장

def alloc_prop(imgs:dict, properties:dict) -> dict:
  """
  이미지가 해당 시리즈의 물성의 최대 최소 값 사이의 값을 가지도록
  물성 값을 랜덤하게 생성후 할당
  """
  # 빈 연결 리스트 생성
  props = {}
  for i in range(1,6):
    props[i] = {}
    for j in ("TS", "YS", "EL"):
      props[i][j] = []

  # 난수 시드 고정
  np.random.seed(0)

  # 생선된 물성 (propserated) 연결 리스트에 저장
  for i in range(1,6):
    for j in ("TS", "YS", "EL"):
      n_min = min(properties[i][j])
      n_max = max(properties[i][j])
      n_imgs = len(imgs[i])
      for _ in range(n_imgs):
        prop_gen = random.choice(range(n_min, n_max+1))
        props[i][j].append(prop_gen)
  return props

props = alloc_prop(imgs,properties)

# check the result
print(f"number of sample series:{list(props.keys())}")
print(f"number of properties:{list(props[1].keys())}")
num_data = [len(props[i]["TS"]) for i in props]
print(f"number of data:{sum(num_data), num_data}")
# Out:
# number of sample series:[1, 2, 3, 4, 5]
# number of properties:['TS', 'YS', 'EL']
# number of data:(600, [150, 150, 150, 150, 0])

# %%
def stack_props(target:str, properties:dict) -> np.array:
  res = []
  for i in props:
    res.extend(props[i][target])
  return np.array(res)

y = stack_props("TS", props)
y = (y-min(y))/ (max(y)-min(y)) # min = 0, max = 1 normalization
print(f"len, min, max of y: {len(y),min(y),max(y)}")
# Out:
# len, min, max of y: (600, 0.0, 1.0)

# %%
def stack_imgs(imgs:dict) -> np.array:
  # 이미지 총 갯수 구하기
  n = sum([len(imgs[i]) for i in imgs])
  # 이미지 차원 구하기
  h,w,c = imgs[1][0].shape # 1번째 시리즈의 1번째 이미지
  # 빈 이미지 변수 생성 -> 미리 만들어주는게 효율적
  imgs_stack = np.empty((n,h,w,c))

  # 이미지 쌓기
  idx = 0
  for i in imgs:
    for img in imgs[i]:
      imgs_stack[idx] = img
      idx += 1
  return imgs_stack

X = stack_imgs(imgs)
print(len(X))
# Out:
# 600

# %% [markdown]
# # 4. 데이터 전처리

# %%
# 훈련 데이터와 검증 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.9, random_state = 0)
print(f"shape of X_train:{X_train.shape}")
print(f"shape of X_test:{X_test.shape}")
print(f"shape of y_train:{y_train.shape}")
print(f"shape of y_test:{y_test.shape}")
print("-"*50)
# 이미지 데이터 정규화
img_transformer = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(
            mean = [0.485, 0.456, 0.406],
            std = [0.229, 0.224, 0.225],
            ),
        ])

# 이미지 데이터 클래스 정의
class img_dataset(Dataset):
  def __init__(self,x,y,transform):
    self.x = x
    self.y = y
    self.T = transform

  def __len__(self):
    return len(self.x)

  def __getitem__(self, idx):
    return self.T(self.x[idx]), self.y[idx]

# 데이터로더에 훈련데이터 격납
train_dataset = img_dataset(X_train, y_train, img_transformer)
test_dataset = img_dataset(X_test, y_test, img_transformer)
train_loader = DataLoader(train_dataset, batch_size = 10, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size = 10, shuffle = True)

# 결과 확인
# tmp = list(iter(train_loader))
# print(f"shape of train batch imgs:{tmp[0][0].shape}")
# print(f"shape of train batch labels:{tmp[0][1].shape}")
# plt.figure(figsize = (4,4))
# plt.imshow(tmp[0][0][0].permute(1,2,0)) # 1st img of the batch
# Out:
# shape of X_train:(540, 448, 448, 3)
# shape of X_test:(60, 448, 448, 3)
# shape of y_train:(540,)
# shape of y_test:(60,)
# --------------------------------------------------

# %% [markdown]
# #5. 모델링

# %%
# loading resnet101
my_model = models.resnet101(pretrained = True)

# change in and out features of fc layer
in_features = my_model.fc.in_features
out_features = 1
my_model.fc = nn.Linear(in_features, out_features)

# freeze parameters when training
for params in my_model.parameters():
  params.requires_grad = True

# unfreeze parameters of fc layer when training
for params in my_model.fc.parameters():
  params.requires_grad = True

# model to device
device = "cuda" if torch.cuda.is_available() else "cpu"
my_model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )

# %% [markdown]
# # 6. 모델 훈련

# %%
# 파라미터 설정
n_epoch = 20
criterion = nn.MSELoss()
optimizer = optim.Adam(my_model.parameters(), lr = 0.00001)

train_loss_lst = []
val_loss_lst = []
for i in range(n_epoch):
  for j,[x,y] in enumerate(train_loader):
    x = x.to(device).to(torch.float32)
    y = y.unsqueeze(1).to(device).to(torch.float32)

    optimizer.zero_grad()
    y_pred = my_model(x)
    loss = criterion(y,y_pred)
    loss.backward()
    optimizer.step()

    train_loss_lst.append(loss.item())


    with torch.no_grad():
      val_loss = 0
      n = 0
      for k, [x_test, y_test] in enumerate(test_loader):
        x_test = x_test.to(device).to(torch.float32)
        y_test = y_test.to(device).to(torch.float32)
        y_test_pred = my_model(x_test).squeeze(1)
        loss_test = criterion(y_test, y_test_pred)
        val_loss += loss_test.item()
        n+=1
    val_loss /= n
    val_loss_lst.append(val_loss)

    # 훈련 진행 상황 출력
    print(f"i:{i}    j:{j}    train_loss:{loss.item():.4f}    val_loss:{val_loss:.3f}    y_val:{y_test[0].item():.3f}    y_val_pred:{y_test_pred[0].item():.3f}")

    # 모델 저장
    if i >= 1 and loss.item() == min(train_loss_lst):
      print("train model saved")
      torch.save(my_model.state_dict(), "./model/train_best_model.pth")

    if i >= 1  and val_loss == min(val_loss_lst):
      print("test model saved")
      torch.save(my_model.state_dict(), "./model/test_best_model.pth")

print("last model saved")
torch.save(my_model.state_dict(), "./model/last_model.pth")
# Out:
# /compuworks/anaconda3/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# i:0    j:0    train_loss:0.0447    val_loss:0.130    y_val:0.266    y_val_pred:0.053
# i:0    j:1    train_loss:0.1441    val_loss:0.109    y_val:0.212    y_val_pred:0.016
# i:0    j:2    train_loss:0.1169    val_loss:0.097    y_val:0.030    y_val_pred:-0.160
# i:0    j:3    train_loss:0.2206    val_loss:0.078    y_val:0.028    y_val_pred:-0.178
# i:0    j:4    train_loss:0.0153    val_loss:0.069    y_val:0.477    y_val_pred:0.184
# i:0    j:5    train_loss:0.0477    val_loss:0.050    y_val:0.212    y_val_pred:0.090
# i:0    j:6    train_loss:0.0748    val_loss:0.054    y_val:0.019    y_val_pred:0.030
# i:0    j:7    train_loss:0.0320    val_loss:0.047    y_val:0.285    y_val_pred:0.140
# i:0    j:8    train_loss:0.0387    val_loss:0.042    y_val:0.019    y_val_pred:-0.194
# i:0    j:9    train_loss:0.0602    val_loss:0.037    y_val:0.311    y_val_pred:0.097
# i:0    j:10    train_loss:0.0197    val_loss:0.039    y_val:0.009    y_val_pred:-0.038
# i:0    j:11    train_loss:0.0309    val_loss:0.036    y_val:0.011    y_val_pred:-0.150
# i:0    j:12    train_loss:0.0531    val_loss:0.033    y_val:0.270    y_val_pred:0.047
# i:0    j:13    train_loss:0.0119    val_loss:0.025    y_val:0.422    y_val_pred:0.484
# i:0    j:14    train_loss:0.0412    val_loss:0.030    y_val:0.477    y_val_pred:0.231
# i:0    j:15    train_loss:0.0102    val_loss:0.020    y_val:0.280    y_val_pred:0.400
# i:0    j:16    train_loss:0.0151    val_loss:0.025    y_val:0.424    y_val_pred:0.294
# i:0    j:17    train_loss:0.0097    val_loss:0.015    y_val:0.424    y_val_pred:0.279
# i:0    j:18    train_loss:0.0173    val_loss:0.020    y_val:0.285    y_val_pred:0.078
# i:0    j:19    train_loss:0.0151    val_loss:0.012    y_val:0.066    y_val_pred:0.028
# i:0    j:20    train_loss:0.0062    val_loss:0.019    y_val:0.492    y_val_pred:0.513
# i:0    j:21    train_loss:0.0185    val_loss:0.021    y_val:0.936    y_val_pred:0.666
# i:0    j:22    train_loss:0.0108    val_loss:0.011    y_val:0.959    y_val_pred:0.759
# i:0    j:23    train_loss:0.0155    val_loss:0.013    y_val:0.302    y_val_pred:0.138
# i:0    j:24    train_loss:0.0073    val_loss:0.017    y_val:0.311    y_val_pred:0.320
# i:0    j:25    train_loss:0.0065    val_loss:0.008    y_val:0.030    y_val_pred:0.236
# i:0    j:26    train_loss:0.0124    val_loss:0.028    y_val:0.304    y_val_pred:0.259
# i:0    j:27    train_loss:0.1152    val_loss:0.010    y_val:0.492    y_val_pred:0.571
# i:0    j:28    train_loss:0.0052    val_loss:0.013    y_val:0.801    y_val_pred:0.747
# i:0    j:29    train_loss:0.0075    val_loss:0.015    y_val:0.886    y_val_pred:0.759
# i:0    j:30    train_loss:0.0060    val_loss:0.012    y_val:0.066    y_val_pred:0.126
# i:0    j:31    train_loss:0.0748    val_loss:0.009    y_val:0.477    y_val_pred:0.420
# i:0    j:32    train_loss:0.0094    val_loss:0.014    y_val:0.936    y_val_pred:0.706
# i:0    j:33    train_loss:0.0082    val_loss:0.018    y_val:0.936    y_val_pred:0.659
# i:0    j:34    train_loss:0.0590    val_loss:0.011    y_val:0.998    y_val_pred:1.032
# i:0    j:35    train_loss:0.0113    val_loss:0.014    y_val:0.805    y_val_pred:1.160
# i:0    j:36    train_loss:0.0286    val_loss:0.018    y_val:0.304    y_val_pred:0.337
# i:0    j:37    train_loss:0.0216    val_loss:0.016    y_val:0.023    y_val_pred:0.364
# i:0    j:38    train_loss:0.0097    val_loss:0.022    y_val:0.936    y_val_pred:0.902
# i:0    j:39    train_loss:0.0451    val_loss:0.015    y_val:0.015    y_val_pred:0.021
# i:0    j:40    train_loss:0.0045    val_loss:0.015    y_val:0.388    y_val_pred:0.362
# i:0    j:41    train_loss:0.0240    val_loss:0.018    y_val:0.424    y_val_pred:0.536
# i:0    j:42    train_loss:0.0065    val_loss:0.016    y_val:0.028    y_val_pred:0.125
# i:0    j:43    train_loss:0.0143    val_loss:0.015    y_val:0.424    y_val_pred:0.612
# i:0    j:44    train_loss:0.0238    val_loss:0.020    y_val:0.477    y_val_pred:0.588
# i:0    j:45    train_loss:0.0076    val_loss:0.023    y_val:0.302    y_val_pred:0.217
# i:0    j:46    train_loss:0.0065    val_loss:0.017    y_val:0.886    y_val_pred:0.815
# i:0    j:47    train_loss:0.0344    val_loss:0.016    y_val:0.019    y_val_pred:0.103
# i:0    j:48    train_loss:0.0096    val_loss:0.016    y_val:0.015    y_val_pred:0.008
# i:0    j:49    train_loss:0.0058    val_loss:0.016    y_val:0.805    y_val_pred:0.987
# i:0    j:50    train_loss:0.0269    val_loss:0.019    y_val:0.311    y_val_pred:0.257
# i:0    j:51    train_loss:0.0027    val_loss:0.021    y_val:0.323    y_val_pred:0.327
# i:0    j:52    train_loss:0.0116    val_loss:0.016    y_val:0.805    y_val_pred:0.995
# i:0    j:53    train_loss:0.0344    val_loss:0.015    y_val:0.266    y_val_pred:0.294
# i:1    j:0    train_loss:0.0165    val_loss:0.014    y_val:0.805    y_val_pred:0.856
# i:1    j:1    train_loss:0.0074    val_loss:0.019    y_val:0.236    y_val_pred:0.474
# i:1    j:2    train_loss:0.0170    val_loss:0.013    y_val:0.805    y_val_pred:1.084
# i:1    j:3    train_loss:0.0140    val_loss:0.011    y_val:0.304    y_val_pred:0.206
# i:1    j:4    train_loss:0.0106    val_loss:0.015    y_val:0.023    y_val_pred:0.127
# i:1    j:5    train_loss:0.0302    val_loss:0.018    y_val:0.482    y_val_pred:0.312
# i:1    j:6    train_loss:0.0043    val_loss:0.015    y_val:0.030    y_val_pred:0.120
# i:1    j:7    train_loss:0.0037    val_loss:0.016    y_val:0.477    y_val_pred:0.314
# i:1    j:8    train_loss:0.0058    val_loss:0.009    y_val:0.323    y_val_pred:0.240
# i:1    j:9    train_loss:0.0093    val_loss:0.010    y_val:0.304    y_val_pred:0.324
# i:1    j:10    train_loss:0.0034    val_loss:0.019    y_val:0.394    y_val_pred:0.332
# i:1    j:11    train_loss:0.0060    val_loss:0.007    y_val:0.936    y_val_pred:0.873
# test model saved
# i:1    j:12    train_loss:0.0415    val_loss:0.010    y_val:0.477    y_val_pred:0.445
# i:1    j:13    train_loss:0.0453    val_loss:0.022    y_val:0.998    y_val_pred:0.903
# i:1    j:14    train_loss:0.0057    val_loss:0.012    y_val:0.199    y_val_pred:0.465
# i:1    j:15    train_loss:0.0024    val_loss:0.010    y_val:0.210    y_val_pred:0.217
# train model saved
# i:1    j:16    train_loss:0.0376    val_loss:0.017    y_val:0.801    y_val_pred:0.876
# i:1    j:17    train_loss:0.0041    val_loss:0.017    y_val:0.236    y_val_pred:0.230
# i:1    j:18    train_loss:0.0277    val_loss:0.024    y_val:0.962    y_val_pred:0.720
# i:1    j:19    train_loss:0.0100    val_loss:0.006    y_val:0.304    y_val_pred:0.336
# test model saved
# i:1    j:20    train_loss:0.0119    val_loss:0.020    y_val:0.426    y_val_pred:0.404
# i:1    j:21    train_loss:0.0040    val_loss:0.016    y_val:0.936    y_val_pred:0.812
# i:1    j:22    train_loss:0.0099    val_loss:0.015    y_val:0.816    y_val_pred:0.969
# i:1    j:23    train_loss:0.0120    val_loss:0.008    y_val:0.492    y_val_pred:0.515
# i:1    j:24    train_loss:0.0107    val_loss:0.018    y_val:0.280    y_val_pred:0.106
# i:1    j:25    train_loss:0.0071    val_loss:0.009    y_val:0.041    y_val_pred:0.064
# i:1    j:26    train_loss:0.0082    val_loss:0.009    y_val:0.199    y_val_pred:0.314
# i:1    j:27    train_loss:0.0270    val_loss:0.014    y_val:0.019    y_val_pred:0.045
# i:1    j:28    train_loss:0.0056    val_loss:0.012    y_val:0.212    y_val_pred:0.092
# i:1    j:29    train_loss:0.0058    val_loss:0.012    y_val:0.028    y_val_pred:0.183
# i:1    j:30    train_loss:0.0246    val_loss:0.018    y_val:0.304    y_val_pred:0.215
# i:1    j:31    train_loss:0.0035    val_loss:0.010    y_val:0.394    y_val_pred:0.337
# i:1    j:32    train_loss:0.0034    val_loss:0.012    y_val:0.452    y_val_pred:0.413
# i:1    j:33    train_loss:0.0081    val_loss:0.013    y_val:0.030    y_val_pred:0.160
# i:1    j:34    train_loss:0.0090    val_loss:0.013    y_val:0.492    y_val_pred:0.495
# i:1    j:35    train_loss:0.0043    val_loss:0.011    y_val:0.302    y_val_pred:0.200
# i:1    j:36    train_loss:0.0057    val_loss:0.012    y_val:0.293    y_val_pred:0.271
# i:1    j:37    train_loss:0.0196    val_loss:0.016    y_val:0.064    y_val_pred:0.121
# i:1    j:38    train_loss:0.0232    val_loss:0.015    y_val:0.066    y_val_pred:0.018
# i:1    j:39    train_loss:0.0197    val_loss:0.012    y_val:0.011    y_val_pred:0.125
# i:1    j:40    train_loss:0.0176    val_loss:0.015    y_val:0.482    y_val_pred:0.477
# i:1    j:41    train_loss:0.0149    val_loss:0.011    y_val:0.477    y_val_pred:0.491
# i:1    j:42    train_loss:0.0126    val_loss:0.012    y_val:0.199    y_val_pred:0.253
# i:1    j:43    train_loss:0.0026    val_loss:0.014    y_val:0.424    y_val_pred:0.420
# i:1    j:44    train_loss:0.0067    val_loss:0.018    y_val:0.212    y_val_pred:0.226
# i:1    j:45    train_loss:0.0032    val_loss:0.013    y_val:0.482    y_val_pred:0.531
# i:1    j:46    train_loss:0.0169    val_loss:0.014    y_val:0.805    y_val_pred:0.969
# i:1    j:47    train_loss:0.0045    val_loss:0.011    y_val:0.302    y_val_pred:0.173
# i:1    j:48    train_loss:0.0114    val_loss:0.016    y_val:0.011    y_val_pred:0.182
# i:1    j:49    train_loss:0.0076    val_loss:0.016    y_val:0.959    y_val_pred:0.722
# i:1    j:50    train_loss:0.0056    val_loss:0.013    y_val:0.311    y_val_pred:0.127
# i:1    j:51    train_loss:0.0063    val_loss:0.009    y_val:0.477    y_val_pred:0.462
# i:1    j:52    train_loss:0.0040    val_loss:0.011    y_val:0.011    y_val_pred:0.232
# i:1    j:53    train_loss:0.0070    val_loss:0.015    y_val:0.304    y_val_pred:0.150
# i:2    j:0    train_loss:0.0100    val_loss:0.009    y_val:0.805    y_val_pred:0.833
# i:2    j:1    train_loss:0.0119    val_loss:0.015    y_val:0.477    y_val_pred:0.452
# i:2    j:2    train_loss:0.0053    val_loss:0.012    y_val:0.340    y_val_pred:0.169
# i:2    j:3    train_loss:0.0151    val_loss:0.024    y_val:0.428    y_val_pred:0.224
# i:2    j:4    train_loss:0.0013    val_loss:0.010    y_val:0.388    y_val_pred:0.453
# train model saved
# i:2    j:5    train_loss:0.0082    val_loss:0.011    y_val:0.388    y_val_pred:0.367
# i:2    j:6    train_loss:0.0077    val_loss:0.012    y_val:0.293    y_val_pred:0.272
# i:2    j:7    train_loss:0.0030    val_loss:0.009    y_val:0.236    y_val_pred:0.260
# i:2    j:8    train_loss:0.0089    val_loss:0.015    y_val:0.422    y_val_pred:0.600
# i:2    j:9    train_loss:0.0233    val_loss:0.010    y_val:0.030    y_val_pred:0.124
# i:2    j:10    train_loss:0.0046    val_loss:0.009    y_val:0.477    y_val_pred:0.386
# i:2    j:11    train_loss:0.0031    val_loss:0.012    y_val:0.477    y_val_pred:0.450
# i:2    j:12    train_loss:0.0013    val_loss:0.008    y_val:0.955    y_val_pred:0.841
# train model saved
# i:2    j:13    train_loss:0.0048    val_loss:0.015    y_val:0.041    y_val_pred:0.081
# i:2    j:14    train_loss:0.0033    val_loss:0.011    y_val:0.023    y_val_pred:0.128
# i:2    j:15    train_loss:0.0149    val_loss:0.014    y_val:0.998    y_val_pred:0.945
# i:2    j:16    train_loss:0.0130    val_loss:0.011    y_val:0.328    y_val_pred:0.209
# i:2    j:17    train_loss:0.0357    val_loss:0.014    y_val:0.302    y_val_pred:0.376
# i:2    j:18    train_loss:0.0277    val_loss:0.012    y_val:0.041    y_val_pred:-0.001
# i:2    j:19    train_loss:0.0219    val_loss:0.009    y_val:0.454    y_val_pred:0.486
# i:2    j:20    train_loss:0.0075    val_loss:0.008    y_val:0.266    y_val_pred:0.275
# i:2    j:21    train_loss:0.0013    val_loss:0.011    y_val:0.028    y_val_pred:-0.052
# i:2    j:22    train_loss:0.0917    val_loss:0.009    y_val:0.236    y_val_pred:0.327
# i:2    j:23    train_loss:0.0066    val_loss:0.008    y_val:0.041    y_val_pred:0.099
# i:2    j:24    train_loss:0.0072    val_loss:0.015    y_val:0.936    y_val_pred:0.846
# i:2    j:25    train_loss:0.0011    val_loss:0.009    y_val:0.428    y_val_pred:0.445
# train model saved
# i:2    j:26    train_loss:0.0038    val_loss:0.010    y_val:0.816    y_val_pred:1.056
# i:2    j:27    train_loss:0.0030    val_loss:0.014    y_val:0.019    y_val_pred:0.003
# i:2    j:28    train_loss:0.0168    val_loss:0.012    y_val:0.394    y_val_pred:0.304
# i:2    j:29    train_loss:0.0267    val_loss:0.007    y_val:0.066    y_val_pred:0.038
# i:2    j:30    train_loss:0.0333    val_loss:0.011    y_val:0.285    y_val_pred:0.255
# i:2    j:31    train_loss:0.0028    val_loss:0.014    y_val:0.019    y_val_pred:0.120
# i:2    j:32    train_loss:0.0069    val_loss:0.017    y_val:0.311    y_val_pred:0.394
# i:2    j:33    train_loss:0.0275    val_loss:0.010    y_val:0.426    y_val_pred:0.425
# i:2    j:34    train_loss:0.0346    val_loss:0.008    y_val:0.452    y_val_pred:0.335
# i:2    j:35    train_loss:0.0522    val_loss:0.009    y_val:0.041    y_val_pred:0.108
# i:2    j:36    train_loss:0.0031    val_loss:0.013    y_val:0.064    y_val_pred:0.153
# i:2    j:37    train_loss:0.0102    val_loss:0.013    y_val:0.805    y_val_pred:0.983
# i:2    j:38    train_loss:0.0072    val_loss:0.014    y_val:0.011    y_val_pred:0.247
# i:2    j:39    train_loss:0.0018    val_loss:0.007    y_val:0.212    y_val_pred:0.243
# i:2    j:40    train_loss:0.0019    val_loss:0.009    y_val:0.064    y_val_pred:0.170
# i:2    j:41    train_loss:0.0065    val_loss:0.008    y_val:0.009    y_val_pred:0.095
# i:2    j:42    train_loss:0.0201    val_loss:0.015    y_val:0.465    y_val_pred:0.427
# i:2    j:43    train_loss:0.1008    val_loss:0.015    y_val:0.340    y_val_pred:0.253
# i:2    j:44    train_loss:0.0044    val_loss:0.011    y_val:0.041    y_val_pred:0.190
# i:2    j:45    train_loss:0.0027    val_loss:0.011    y_val:0.030    y_val_pred:0.159
# i:2    j:46    train_loss:0.0065    val_loss:0.014    y_val:0.028    y_val_pred:0.134
# i:2    j:47    train_loss:0.0159    val_loss:0.012    y_val:0.959    y_val_pred:0.785
# i:2    j:48    train_loss:0.0075    val_loss:0.011    y_val:0.428    y_val_pred:0.355
# i:2    j:49    train_loss:0.0072    val_loss:0.008    y_val:0.328    y_val_pred:0.313
# i:2    j:50    train_loss:0.0061    val_loss:0.014    y_val:0.428    y_val_pred:0.410
# i:2    j:51    train_loss:0.0304    val_loss:0.009    y_val:0.199    y_val_pred:0.267
# i:2    j:52    train_loss:0.0142    val_loss:0.013    y_val:0.019    y_val_pred:0.164
# i:2    j:53    train_loss:0.0044    val_loss:0.013    y_val:0.955    y_val_pred:0.927
# i:3    j:0    train_loss:0.0086    val_loss:0.009    y_val:0.064    y_val_pred:0.024
# i:3    j:1    train_loss:0.0020    val_loss:0.010    y_val:0.805    y_val_pred:0.971
# i:3    j:2    train_loss:0.0044    val_loss:0.012    y_val:0.871    y_val_pred:0.876
# i:3    j:3    train_loss:0.0036    val_loss:0.007    y_val:0.028    y_val_pred:0.101
# i:3    j:4    train_loss:0.0189    val_loss:0.015    y_val:0.955    y_val_pred:0.824
# i:3    j:5    train_loss:0.0096    val_loss:0.010    y_val:0.962    y_val_pred:0.980
# i:3    j:6    train_loss:0.0060    val_loss:0.009    y_val:0.936    y_val_pred:0.895
# i:3    j:7    train_loss:0.0023    val_loss:0.018    y_val:0.477    y_val_pred:0.387
# i:3    j:8    train_loss:0.0077    val_loss:0.010    y_val:0.340    y_val_pred:0.199
# i:3    j:9    train_loss:0.0108    val_loss:0.011    y_val:0.212    y_val_pred:0.260
# i:3    j:10    train_loss:0.0119    val_loss:0.013    y_val:0.340    y_val_pred:0.327
# i:3    j:11    train_loss:0.0017    val_loss:0.007    y_val:0.064    y_val_pred:0.044
# i:3    j:12    train_loss:0.0016    val_loss:0.010    y_val:0.311    y_val_pred:0.182
# i:3    j:13    train_loss:0.0023    val_loss:0.009    y_val:0.285    y_val_pred:0.190
# i:3    j:14    train_loss:0.0136    val_loss:0.006    y_val:0.023    y_val_pred:0.155
# i:3    j:15    train_loss:0.0061    val_loss:0.015    y_val:0.285    y_val_pred:0.184
# i:3    j:16    train_loss:0.0245    val_loss:0.014    y_val:0.266    y_val_pred:0.327
# i:3    j:17    train_loss:0.0056    val_loss:0.015    y_val:0.482    y_val_pred:0.453
# i:3    j:18    train_loss:0.0020    val_loss:0.007    y_val:0.959    y_val_pred:0.771
# i:3    j:19    train_loss:0.0045    val_loss:0.009    y_val:0.422    y_val_pred:0.561
# i:3    j:20    train_loss:0.0096    val_loss:0.011    y_val:0.452    y_val_pred:0.605
# i:3    j:21    train_loss:0.0030    val_loss:0.009    y_val:0.323    y_val_pred:0.223
# i:3    j:22    train_loss:0.0051    val_loss:0.011    y_val:0.199    y_val_pred:0.284
# i:3    j:23    train_loss:0.0506    val_loss:0.010    y_val:0.805    y_val_pred:0.922
# i:3    j:24    train_loss:0.0130    val_loss:0.009    y_val:0.394    y_val_pred:0.435
# i:3    j:25    train_loss:0.0020    val_loss:0.010    y_val:0.936    y_val_pred:0.880
# i:3    j:26    train_loss:0.0028    val_loss:0.012    y_val:0.199    y_val_pred:0.137
# i:3    j:27    train_loss:0.0022    val_loss:0.007    y_val:0.051    y_val_pred:-0.007
# i:3    j:28    train_loss:0.0085    val_loss:0.007    y_val:0.388    y_val_pred:0.350
# i:3    j:29    train_loss:0.0190    val_loss:0.005    y_val:0.323    y_val_pred:0.193
# test model saved
# i:3    j:30    train_loss:0.0028    val_loss:0.007    y_val:0.477    y_val_pred:0.472
# i:3    j:31    train_loss:0.0350    val_loss:0.008    y_val:0.805    y_val_pred:0.830
# i:3    j:32    train_loss:0.0053    val_loss:0.005    y_val:0.304    y_val_pred:0.326
# i:3    j:33    train_loss:0.0068    val_loss:0.007    y_val:0.311    y_val_pred:0.198
# i:3    j:34    train_loss:0.0212    val_loss:0.012    y_val:0.388    y_val_pred:0.391
# i:3    j:35    train_loss:0.0023    val_loss:0.009    y_val:0.492    y_val_pred:0.558
# i:3    j:36    train_loss:0.0019    val_loss:0.009    y_val:0.492    y_val_pred:0.421
# i:3    j:37    train_loss:0.0026    val_loss:0.010    y_val:0.962    y_val_pred:0.938
# i:3    j:38    train_loss:0.0066    val_loss:0.014    y_val:0.452    y_val_pred:0.557
# i:3    j:39    train_loss:0.0174    val_loss:0.024    y_val:0.936    y_val_pred:0.953
# i:3    j:40    train_loss:0.0159    val_loss:0.013    y_val:0.871    y_val_pred:0.977
# i:3    j:41    train_loss:0.0026    val_loss:0.010    y_val:0.424    y_val_pred:0.401
# i:3    j:42    train_loss:0.0075    val_loss:0.010    y_val:0.323    y_val_pred:0.367
# i:3    j:43    train_loss:0.0060    val_loss:0.014    y_val:0.236    y_val_pred:0.193
# i:3    j:44    train_loss:0.0093    val_loss:0.009    y_val:0.492    y_val_pred:0.580
# i:3    j:45    train_loss:0.0063    val_loss:0.008    y_val:0.302    y_val_pred:0.266
# i:3    j:46    train_loss:0.0015    val_loss:0.010    y_val:0.302    y_val_pred:0.223
# i:3    j:47    train_loss:0.0135    val_loss:0.012    y_val:0.424    y_val_pred:0.531
# i:3    j:48    train_loss:0.0044    val_loss:0.007    y_val:0.467    y_val_pred:0.496
# i:3    j:49    train_loss:0.0039    val_loss:0.009    y_val:0.293    y_val_pred:0.222
# i:3    j:50    train_loss:0.0082    val_loss:0.009    y_val:0.454    y_val_pred:0.410
# i:3    j:51    train_loss:0.0060    val_loss:0.018    y_val:0.199    y_val_pred:0.338
# i:3    j:52    train_loss:0.0021    val_loss:0.016    y_val:0.285    y_val_pred:0.218
# i:3    j:53    train_loss:0.0163    val_loss:0.008    y_val:0.428    y_val_pred:0.459
# i:4    j:0    train_loss:0.0192    val_loss:0.009    y_val:0.015    y_val_pred:0.103
# i:4    j:1    train_loss:0.0030    val_loss:0.013    y_val:0.962    y_val_pred:0.898
# i:4    j:2    train_loss:0.0006    val_loss:0.009    y_val:0.266    y_val_pred:0.274
# train model saved
# i:4    j:3    train_loss:0.0047    val_loss:0.014    y_val:0.424    y_val_pred:0.451
# i:4    j:4    train_loss:0.0050    val_loss:0.010    y_val:0.011    y_val_pred:0.155
# i:4    j:5    train_loss:0.0010    val_loss:0.007    y_val:0.955    y_val_pred:0.989
# i:4    j:6    train_loss:0.0100    val_loss:0.018    y_val:0.465    y_val_pred:0.474
# i:4    j:7    train_loss:0.0065    val_loss:0.009    y_val:0.428    y_val_pred:0.446
# i:4    j:8    train_loss:0.0044    val_loss:0.011    y_val:0.015    y_val_pred:-0.029
# i:4    j:9    train_loss:0.0209    val_loss:0.013    y_val:0.452    y_val_pred:0.377
# i:4    j:10    train_loss:0.0115    val_loss:0.010    y_val:0.388    y_val_pred:0.321
# i:4    j:11    train_loss:0.0045    val_loss:0.015    y_val:0.064    y_val_pred:0.188
# i:4    j:12    train_loss:0.0062    val_loss:0.011    y_val:0.426    y_val_pred:0.384
# i:4    j:13    train_loss:0.0168    val_loss:0.013    y_val:0.028    y_val_pred:0.094
# i:4    j:14    train_loss:0.0011    val_loss:0.007    y_val:0.015    y_val_pred:0.092
# i:4    j:15    train_loss:0.0170    val_loss:0.007    y_val:0.009    y_val_pred:0.070
# i:4    j:16    train_loss:0.0036    val_loss:0.010    y_val:0.304    y_val_pred:0.223
# i:4    j:17    train_loss:0.0019    val_loss:0.008    y_val:0.477    y_val_pred:0.536
# i:4    j:18    train_loss:0.0068    val_loss:0.008    y_val:0.028    y_val_pred:0.134
# i:4    j:19    train_loss:0.0019    val_loss:0.012    y_val:0.011    y_val_pred:0.080
# i:4    j:20    train_loss:0.0052    val_loss:0.013    y_val:0.418    y_val_pred:0.478
# i:4    j:21    train_loss:0.0080    val_loss:0.012    y_val:0.199    y_val_pred:0.396
# i:4    j:22    train_loss:0.0268    val_loss:0.007    y_val:0.998    y_val_pred:0.868
# i:4    j:23    train_loss:0.0030    val_loss:0.011    y_val:0.805    y_val_pred:0.739
# i:4    j:24    train_loss:0.0026    val_loss:0.007    y_val:0.998    y_val_pred:0.869
# i:4    j:25    train_loss:0.0045    val_loss:0.012    y_val:0.210    y_val_pred:0.418
# i:4    j:26    train_loss:0.0082    val_loss:0.009    y_val:0.805    y_val_pred:0.743
# i:4    j:27    train_loss:0.0149    val_loss:0.005    y_val:0.328    y_val_pred:0.282
# i:4    j:28    train_loss:0.0013    val_loss:0.008    y_val:0.066    y_val_pred:0.095
# i:4    j:29    train_loss:0.0158    val_loss:0.005    y_val:0.388    y_val_pred:0.397
# test model saved
# i:4    j:30    train_loss:0.0047    val_loss:0.011    y_val:0.009    y_val_pred:0.134
# i:4    j:31    train_loss:0.0035    val_loss:0.010    y_val:0.011    y_val_pred:0.042
# i:4    j:32    train_loss:0.0013    val_loss:0.008    y_val:0.019    y_val_pred:0.050
# i:4    j:33    train_loss:0.0032    val_loss:0.007    y_val:0.328    y_val_pred:0.267
# i:4    j:34    train_loss:0.0029    val_loss:0.015    y_val:0.962    y_val_pred:0.947
# i:4    j:35    train_loss:0.0105    val_loss:0.006    y_val:0.212    y_val_pred:0.308
# i:4    j:36    train_loss:0.0262    val_loss:0.007    y_val:0.323    y_val_pred:0.182
# i:4    j:37    train_loss:0.0052    val_loss:0.010    y_val:0.871    y_val_pred:0.926
# i:4    j:38    train_loss:0.0030    val_loss:0.005    y_val:0.266    y_val_pred:0.247
# test model saved
# i:4    j:39    train_loss:0.0283    val_loss:0.010    y_val:0.019    y_val_pred:0.141
# i:4    j:40    train_loss:0.0034    val_loss:0.008    y_val:0.801    y_val_pred:0.798
# i:4    j:41    train_loss:0.0033    val_loss:0.005    y_val:0.293    y_val_pred:0.230
# i:4    j:42    train_loss:0.0031    val_loss:0.007    y_val:0.465    y_val_pred:0.423
# i:4    j:43    train_loss:0.0069    val_loss:0.010    y_val:0.340    y_val_pred:0.359
# i:4    j:44    train_loss:0.0021    val_loss:0.009    y_val:0.019    y_val_pred:0.109
# i:4    j:45    train_loss:0.0061    val_loss:0.009    y_val:0.424    y_val_pred:0.480
# i:4    j:46    train_loss:0.0041    val_loss:0.007    y_val:0.801    y_val_pred:0.850
# i:4    j:47    train_loss:0.0033    val_loss:0.007    y_val:0.019    y_val_pred:0.074
# i:4    j:48    train_loss:0.0144    val_loss:0.014    y_val:0.210    y_val_pred:0.460
# i:4    j:49    train_loss:0.0066    val_loss:0.008    y_val:0.311    y_val_pred:0.345
# i:4    j:50    train_loss:0.0029    val_loss:0.006    y_val:0.936    y_val_pred:0.816
# i:4    j:51    train_loss:0.0009    val_loss:0.015    y_val:0.028    y_val_pred:0.061
# i:4    j:52    train_loss:0.0011    val_loss:0.009    y_val:0.199    y_val_pred:0.180
# i:4    j:53    train_loss:0.0021    val_loss:0.007    y_val:0.477    y_val_pred:0.522
# i:5    j:0    train_loss:0.0200    val_loss:0.008    y_val:0.424    y_val_pred:0.486
# i:5    j:1    train_loss:0.0079    val_loss:0.012    y_val:0.998    y_val_pred:0.961
# i:5    j:2    train_loss:0.0029    val_loss:0.009    y_val:0.280    y_val_pred:0.223
# i:5    j:3    train_loss:0.0064    val_loss:0.006    y_val:0.015    y_val_pred:-0.052
# i:5    j:4    train_loss:0.0134    val_loss:0.010    y_val:0.998    y_val_pred:0.934
# i:5    j:5    train_loss:0.0076    val_loss:0.005    y_val:0.467    y_val_pred:0.498
# i:5    j:6    train_loss:0.0125    val_loss:0.011    y_val:0.492    y_val_pred:0.543
# i:5    j:7    train_loss:0.0059    val_loss:0.009    y_val:0.028    y_val_pred:0.070
# i:5    j:8    train_loss:0.0090    val_loss:0.007    y_val:0.871    y_val_pred:0.815
# i:5    j:9    train_loss:0.0279    val_loss:0.008    y_val:0.019    y_val_pred:0.077
# i:5    j:10    train_loss:0.0051    val_loss:0.005    y_val:0.424    y_val_pred:0.450
# i:5    j:11    train_loss:0.0010    val_loss:0.007    y_val:0.340    y_val_pred:0.195
# i:5    j:12    train_loss:0.0039    val_loss:0.014    y_val:0.019    y_val_pred:0.134
# i:5    j:13    train_loss:0.0028    val_loss:0.011    y_val:0.482    y_val_pred:0.536
# i:5    j:14    train_loss:0.0028    val_loss:0.012    y_val:0.816    y_val_pred:0.975
# i:5    j:15    train_loss:0.0053    val_loss:0.009    y_val:0.323    y_val_pred:0.209
# i:5    j:16    train_loss:0.0052    val_loss:0.010    y_val:0.424    y_val_pred:0.317
# i:5    j:17    train_loss:0.0034    val_loss:0.007    y_val:0.019    y_val_pred:0.079
# i:5    j:18    train_loss:0.0337    val_loss:0.008    y_val:0.009    y_val_pred:0.108
# i:5    j:19    train_loss:0.0081    val_loss:0.009    y_val:0.030    y_val_pred:0.111
# i:5    j:20    train_loss:0.0054    val_loss:0.006    y_val:0.199    y_val_pred:0.354
# i:5    j:21    train_loss:0.0206    val_loss:0.007    y_val:0.015    y_val_pred:0.075
# i:5    j:22    train_loss:0.0036    val_loss:0.008    y_val:0.465    y_val_pred:0.412
# i:5    j:23    train_loss:0.0212    val_loss:0.009    y_val:0.009    y_val_pred:0.041
# i:5    j:24    train_loss:0.0054    val_loss:0.008    y_val:0.886    y_val_pred:0.900
# i:5    j:25    train_loss:0.0069    val_loss:0.007    y_val:0.871    y_val_pred:0.985
# i:5    j:26    train_loss:0.0052    val_loss:0.017    y_val:0.030    y_val_pred:0.392
# i:5    j:27    train_loss:0.0114    val_loss:0.008    y_val:0.424    y_val_pred:0.394
# i:5    j:28    train_loss:0.0079    val_loss:0.011    y_val:0.465    y_val_pred:0.439
# i:5    j:29    train_loss:0.0062    val_loss:0.014    y_val:0.293    y_val_pred:0.341
# i:5    j:30    train_loss:0.0088    val_loss:0.012    y_val:0.019    y_val_pred:0.134
# i:5    j:31    train_loss:0.0009    val_loss:0.013    y_val:0.285    y_val_pred:0.216
# i:5    j:32    train_loss:0.0039    val_loss:0.016    y_val:0.955    y_val_pred:0.856
# i:5    j:33    train_loss:0.0025    val_loss:0.017    y_val:0.015    y_val_pred:0.055
# i:5    j:34    train_loss:0.0178    val_loss:0.011    y_val:0.270    y_val_pred:0.346
# i:5    j:35    train_loss:0.0056    val_loss:0.010    y_val:0.959    y_val_pred:0.844
# i:5    j:36    train_loss:0.0044    val_loss:0.016    y_val:0.236    y_val_pred:0.450
# i:5    j:37    train_loss:0.0016    val_loss:0.015    y_val:0.302    y_val_pred:0.230
# i:5    j:38    train_loss:0.0330    val_loss:0.016    y_val:0.280    y_val_pred:0.438
# i:5    j:39    train_loss:0.0028    val_loss:0.011    y_val:0.028    y_val_pred:0.077
# i:5    j:40    train_loss:0.0191    val_loss:0.008    y_val:0.492    y_val_pred:0.725
# i:5    j:41    train_loss:0.0023    val_loss:0.014    y_val:0.492    y_val_pred:0.418
# i:5    j:42    train_loss:0.0066    val_loss:0.010    y_val:0.886    y_val_pred:0.912
# i:5    j:43    train_loss:0.0044    val_loss:0.010    y_val:0.030    y_val_pred:0.131
# i:5    j:44    train_loss:0.0013    val_loss:0.008    y_val:0.454    y_val_pred:0.517
# i:5    j:45    train_loss:0.0012    val_loss:0.012    y_val:0.426    y_val_pred:0.496
# i:5    j:46    train_loss:0.0078    val_loss:0.015    y_val:0.428    y_val_pred:0.223
# i:5    j:47    train_loss:0.0119    val_loss:0.007    y_val:0.280    y_val_pred:0.319
# i:5    j:48    train_loss:0.0019    val_loss:0.015    y_val:0.428    y_val_pred:0.499
# i:5    j:49    train_loss:0.0066    val_loss:0.012    y_val:0.422    y_val_pred:0.588
# i:5    j:50    train_loss:0.0019    val_loss:0.006    y_val:0.886    y_val_pred:0.792
# i:5    j:51    train_loss:0.0035    val_loss:0.011    y_val:0.019    y_val_pred:0.133
# i:5    j:52    train_loss:0.0011    val_loss:0.007    y_val:0.454    y_val_pred:0.353
# i:5    j:53    train_loss:0.0020    val_loss:0.011    y_val:0.280    y_val_pred:0.182
# i:6    j:0    train_loss:0.0060    val_loss:0.008    y_val:0.452    y_val_pred:0.370
# i:6    j:1    train_loss:0.0014    val_loss:0.009    y_val:0.454    y_val_pred:0.435
# i:6    j:2    train_loss:0.0019    val_loss:0.009    y_val:0.467    y_val_pred:0.347
# i:6    j:3    train_loss:0.0089    val_loss:0.005    y_val:0.340    y_val_pred:0.264
# i:6    j:4    train_loss:0.0099    val_loss:0.008    y_val:0.452    y_val_pred:0.534
# i:6    j:5    train_loss:0.0023    val_loss:0.012    y_val:0.066    y_val_pred:0.062
# i:6    j:6    train_loss:0.0086    val_loss:0.010    y_val:0.388    y_val_pred:0.408
# i:6    j:7    train_loss:0.0065    val_loss:0.007    y_val:0.066    y_val_pred:0.108
# i:6    j:8    train_loss:0.0030    val_loss:0.010    y_val:0.452    y_val_pred:0.432
# i:6    j:9    train_loss:0.0197    val_loss:0.008    y_val:0.477    y_val_pred:0.502
# i:6    j:10    train_loss:0.0048    val_loss:0.016    y_val:0.323    y_val_pred:0.263
# i:6    j:11    train_loss:0.0115    val_loss:0.010    y_val:0.805    y_val_pred:0.820
# i:6    j:12    train_loss:0.0115    val_loss:0.013    y_val:0.452    y_val_pred:0.508
# i:6    j:13    train_loss:0.0070    val_loss:0.012    y_val:0.482    y_val_pred:0.403
# i:6    j:14    train_loss:0.0047    val_loss:0.014    y_val:0.311    y_val_pred:0.291
# i:6    j:15    train_loss:0.0065    val_loss:0.014    y_val:0.302    y_val_pred:0.218
# i:6    j:16    train_loss:0.0035    val_loss:0.016    y_val:0.270    y_val_pred:0.407
# i:6    j:17    train_loss:0.0076    val_loss:0.016    y_val:0.477    y_val_pred:0.334
# i:6    j:18    train_loss:0.0006    val_loss:0.011    y_val:0.009    y_val_pred:0.056
# train model saved
# i:6    j:19    train_loss:0.0107    val_loss:0.012    y_val:0.936    y_val_pred:1.035
# i:6    j:20    train_loss:0.0015    val_loss:0.014    y_val:0.340    y_val_pred:0.289
# i:6    j:21    train_loss:0.0037    val_loss:0.016    y_val:0.270    y_val_pred:0.379
# i:6    j:22    train_loss:0.0249    val_loss:0.010    y_val:0.801    y_val_pred:0.933
# i:6    j:23    train_loss:0.0106    val_loss:0.009    y_val:0.328    y_val_pred:0.293
# i:6    j:24    train_loss:0.0015    val_loss:0.009    y_val:0.492    y_val_pred:0.447
# i:6    j:25    train_loss:0.0016    val_loss:0.014    y_val:0.424    y_val_pred:0.442
# i:6    j:26    train_loss:0.0086    val_loss:0.010    y_val:0.302    y_val_pred:0.256
# i:6    j:27    train_loss:0.0087    val_loss:0.007    y_val:0.477    y_val_pred:0.404
# i:6    j:28    train_loss:0.0145    val_loss:0.007    y_val:0.801    y_val_pred:0.872
# i:6    j:29    train_loss:0.0178    val_loss:0.008    y_val:0.424    y_val_pred:0.410
# i:6    j:30    train_loss:0.0019    val_loss:0.006    y_val:0.236    y_val_pred:0.306
# i:6    j:31    train_loss:0.0013    val_loss:0.007    y_val:0.482    y_val_pred:0.475
# i:6    j:32    train_loss:0.0238    val_loss:0.006    y_val:0.015    y_val_pred:0.122
# i:6    j:33    train_loss:0.0018    val_loss:0.005    y_val:0.424    y_val_pred:0.461
# i:6    j:34    train_loss:0.0023    val_loss:0.006    y_val:0.066    y_val_pred:0.052
# i:6    j:35    train_loss:0.0019    val_loss:0.007    y_val:0.805    y_val_pred:0.792
# i:6    j:36    train_loss:0.0050    val_loss:0.007    y_val:0.051    y_val_pred:0.093
# i:6    j:37    train_loss:0.0048    val_loss:0.007    y_val:0.936    y_val_pred:0.794
# i:6    j:38    train_loss:0.0520    val_loss:0.009    y_val:0.212    y_val_pred:0.152
# i:6    j:39    train_loss:0.0015    val_loss:0.007    y_val:0.328    y_val_pred:0.218
# i:6    j:40    train_loss:0.0011    val_loss:0.008    y_val:0.041    y_val_pred:0.109
# i:6    j:41    train_loss:0.0042    val_loss:0.014    y_val:0.959    y_val_pred:0.670
# i:6    j:42    train_loss:0.0040    val_loss:0.006    y_val:0.030    y_val_pred:0.055
# i:6    j:43    train_loss:0.0049    val_loss:0.006    y_val:0.323    y_val_pred:0.207
# i:6    j:44    train_loss:0.0028    val_loss:0.006    y_val:0.886    y_val_pred:0.880
# i:6    j:45    train_loss:0.0029    val_loss:0.006    y_val:0.388    y_val_pred:0.460
# i:6    j:46    train_loss:0.0024    val_loss:0.008    y_val:0.015    y_val_pred:0.069
# i:6    j:47    train_loss:0.0059    val_loss:0.006    y_val:0.482    y_val_pred:0.359
# i:6    j:48    train_loss:0.0009    val_loss:0.005    y_val:0.805    y_val_pred:0.940
# i:6    j:49    train_loss:0.0039    val_loss:0.007    y_val:0.805    y_val_pred:0.719
# i:6    j:50    train_loss:0.0022    val_loss:0.009    y_val:0.323    y_val_pred:0.172
# i:6    j:51    train_loss:0.0104    val_loss:0.007    y_val:0.328    y_val_pred:0.279
# i:6    j:52    train_loss:0.0110    val_loss:0.008    y_val:0.015    y_val_pred:-0.006
# i:6    j:53    train_loss:0.0046    val_loss:0.006    y_val:0.266    y_val_pred:0.341
# i:7    j:0    train_loss:0.0018    val_loss:0.007    y_val:0.340    y_val_pred:0.289
# i:7    j:1    train_loss:0.0016    val_loss:0.006    y_val:0.428    y_val_pred:0.385
# i:7    j:2    train_loss:0.0090    val_loss:0.005    y_val:0.011    y_val_pred:-0.032
# i:7    j:3    train_loss:0.0015    val_loss:0.009    y_val:0.477    y_val_pred:0.387
# i:7    j:4    train_loss:0.0342    val_loss:0.009    y_val:0.340    y_val_pred:0.223
# i:7    j:5    train_loss:0.0077    val_loss:0.006    y_val:0.019    y_val_pred:0.066
# i:7    j:6    train_loss:0.0045    val_loss:0.014    y_val:0.424    y_val_pred:0.391
# i:7    j:7    train_loss:0.0032    val_loss:0.009    y_val:0.028    y_val_pred:0.007
# i:7    j:8    train_loss:0.0058    val_loss:0.008    y_val:0.871    y_val_pred:0.798
# i:7    j:9    train_loss:0.0020    val_loss:0.008    y_val:0.998    y_val_pred:0.799
# i:7    j:10    train_loss:0.0031    val_loss:0.008    y_val:0.304    y_val_pred:0.202
# i:7    j:11    train_loss:0.0078    val_loss:0.004    y_val:0.340    y_val_pred:0.299
# test model saved
# i:7    j:12    train_loss:0.0021    val_loss:0.006    y_val:0.019    y_val_pred:0.070
# i:7    j:13    train_loss:0.0024    val_loss:0.006    y_val:0.328    y_val_pred:0.336
# i:7    j:14    train_loss:0.0073    val_loss:0.005    y_val:0.492    y_val_pred:0.556
# i:7    j:15    train_loss:0.0040    val_loss:0.009    y_val:0.066    y_val_pred:0.098
# i:7    j:16    train_loss:0.0036    val_loss:0.007    y_val:0.199    y_val_pred:0.274
# i:7    j:17    train_loss:0.0023    val_loss:0.006    y_val:0.285    y_val_pred:0.273
# i:7    j:18    train_loss:0.0014    val_loss:0.010    y_val:0.394    y_val_pred:0.474
# i:7    j:19    train_loss:0.0024    val_loss:0.006    y_val:0.886    y_val_pred:0.928
# i:7    j:20    train_loss:0.0009    val_loss:0.008    y_val:0.015    y_val_pred:0.051
# i:7    j:21    train_loss:0.0058    val_loss:0.008    y_val:0.871    y_val_pred:0.794
# i:7    j:22    train_loss:0.0023    val_loss:0.008    y_val:0.388    y_val_pred:0.458
# i:7    j:23    train_loss:0.0007    val_loss:0.005    y_val:0.323    y_val_pred:0.368
# i:7    j:24    train_loss:0.0115    val_loss:0.009    y_val:0.210    y_val_pred:0.400
# i:7    j:25    train_loss:0.0011    val_loss:0.014    y_val:0.467    y_val_pred:0.517
# i:7    j:26    train_loss:0.0008    val_loss:0.013    y_val:0.428    y_val_pred:0.444
# i:7    j:27    train_loss:0.0055    val_loss:0.006    y_val:0.454    y_val_pred:0.432
# i:7    j:28    train_loss:0.0039    val_loss:0.009    y_val:0.212    y_val_pred:0.373
# i:7    j:29    train_loss:0.0034    val_loss:0.012    y_val:0.477    y_val_pred:0.437
# i:7    j:30    train_loss:0.0059    val_loss:0.009    y_val:0.236    y_val_pred:0.290
# i:7    j:31    train_loss:0.0033    val_loss:0.012    y_val:0.871    y_val_pred:0.935
# i:7    j:32    train_loss:0.0101    val_loss:0.005    y_val:0.293    y_val_pred:0.296
# i:7    j:33    train_loss:0.0187    val_loss:0.010    y_val:0.304    y_val_pred:0.316
# i:7    j:34    train_loss:0.0021    val_loss:0.009    y_val:0.270    y_val_pred:0.180
# i:7    j:35    train_loss:0.0023    val_loss:0.011    y_val:0.015    y_val_pred:0.154
# i:7    j:36    train_loss:0.0066    val_loss:0.005    y_val:0.270    y_val_pred:0.265
# i:7    j:37    train_loss:0.0193    val_loss:0.006    y_val:0.323    y_val_pred:0.164
# i:7    j:38    train_loss:0.0047    val_loss:0.010    y_val:0.019    y_val_pred:0.039
# i:7    j:39    train_loss:0.0214    val_loss:0.007    y_val:0.051    y_val_pred:0.076
# i:7    j:40    train_loss:0.0044    val_loss:0.010    y_val:0.302    y_val_pred:0.185
# i:7    j:41    train_loss:0.0445    val_loss:0.009    y_val:0.285    y_val_pred:0.266
# i:7    j:42    train_loss:0.0027    val_loss:0.007    y_val:0.323    y_val_pred:0.247
# i:7    j:43    train_loss:0.0049    val_loss:0.007    y_val:0.270    y_val_pred:0.210
# i:7    j:44    train_loss:0.0110    val_loss:0.013    y_val:0.426    y_val_pred:0.437
# i:7    j:45    train_loss:0.0061    val_loss:0.007    y_val:0.064    y_val_pred:0.128
# i:7    j:46    train_loss:0.0021    val_loss:0.007    y_val:0.477    y_val_pred:0.385
# i:7    j:47    train_loss:0.0539    val_loss:0.006    y_val:0.199    y_val_pred:0.306
# i:7    j:48    train_loss:0.0009    val_loss:0.010    y_val:0.955    y_val_pred:0.790
# i:7    j:49    train_loss:0.0524    val_loss:0.007    y_val:0.394    y_val_pred:0.451
# i:7    j:50    train_loss:0.0059    val_loss:0.008    y_val:0.266    y_val_pred:0.275
# i:7    j:51    train_loss:0.0056    val_loss:0.006    y_val:0.266    y_val_pred:0.303
# i:7    j:52    train_loss:0.0033    val_loss:0.007    y_val:0.467    y_val_pred:0.523
# i:7    j:53    train_loss:0.0190    val_loss:0.006    y_val:0.871    y_val_pred:0.859
# i:8    j:0    train_loss:0.0013    val_loss:0.007    y_val:0.212    y_val_pred:0.243
# i:8    j:1    train_loss:0.0102    val_loss:0.007    y_val:0.285    y_val_pred:0.217
# i:8    j:2    train_loss:0.0041    val_loss:0.009    y_val:0.428    y_val_pred:0.423
# i:8    j:3    train_loss:0.0094    val_loss:0.009    y_val:0.210    y_val_pred:0.390
# i:8    j:4    train_loss:0.0064    val_loss:0.010    y_val:0.028    y_val_pred:0.169
# i:8    j:5    train_loss:0.0117    val_loss:0.009    y_val:0.424    y_val_pred:0.476
# i:8    j:6    train_loss:0.0022    val_loss:0.008    y_val:0.886    y_val_pred:0.870
# i:8    j:7    train_loss:0.0180    val_loss:0.006    y_val:0.886    y_val_pred:0.823
# i:8    j:8    train_loss:0.0008    val_loss:0.006    y_val:0.009    y_val_pred:0.047
# i:8    j:9    train_loss:0.0020    val_loss:0.007    y_val:0.477    y_val_pred:0.324
# i:8    j:10    train_loss:0.0055    val_loss:0.007    y_val:0.028    y_val_pred:-0.019
# i:8    j:11    train_loss:0.0025    val_loss:0.008    y_val:0.816    y_val_pred:0.867
# i:8    j:12    train_loss:0.0022    val_loss:0.009    y_val:0.266    y_val_pred:0.232
# i:8    j:13    train_loss:0.0018    val_loss:0.006    y_val:0.285    y_val_pred:0.285
# i:8    j:14    train_loss:0.0021    val_loss:0.007    y_val:0.304    y_val_pred:0.210
# i:8    j:15    train_loss:0.0049    val_loss:0.009    y_val:0.936    y_val_pred:0.931
# i:8    j:16    train_loss:0.0012    val_loss:0.006    y_val:0.936    y_val_pred:0.959
# i:8    j:17    train_loss:0.0031    val_loss:0.004    y_val:0.266    y_val_pred:0.177
# test model saved
# i:8    j:18    train_loss:0.0046    val_loss:0.007    y_val:0.801    y_val_pred:0.880
# i:8    j:19    train_loss:0.0170    val_loss:0.009    y_val:0.009    y_val_pred:0.083
# i:8    j:20    train_loss:0.0026    val_loss:0.009    y_val:0.816    y_val_pred:0.865
# i:8    j:21    train_loss:0.0015    val_loss:0.005    y_val:0.023    y_val_pred:0.041
# i:8    j:22    train_loss:0.0019    val_loss:0.007    y_val:0.340    y_val_pred:0.210
# i:8    j:23    train_loss:0.0008    val_loss:0.006    y_val:0.871    y_val_pred:0.875
# i:8    j:24    train_loss:0.0038    val_loss:0.006    y_val:0.936    y_val_pred:0.942
# i:8    j:25    train_loss:0.0032    val_loss:0.006    y_val:0.426    y_val_pred:0.481
# i:8    j:26    train_loss:0.0014    val_loss:0.007    y_val:0.019    y_val_pred:0.056
# i:8    j:27    train_loss:0.0020    val_loss:0.005    y_val:0.886    y_val_pred:0.854
# i:8    j:28    train_loss:0.0046    val_loss:0.010    y_val:0.328    y_val_pred:0.169
# i:8    j:29    train_loss:0.0028    val_loss:0.011    y_val:0.477    y_val_pred:0.395
# i:8    j:30    train_loss:0.0049    val_loss:0.006    y_val:0.019    y_val_pred:0.058
# i:8    j:31    train_loss:0.0054    val_loss:0.008    y_val:0.199    y_val_pred:0.276
# i:8    j:32    train_loss:0.0040    val_loss:0.007    y_val:0.028    y_val_pred:0.091
# i:8    j:33    train_loss:0.0025    val_loss:0.006    y_val:0.340    y_val_pred:0.301
# i:8    j:34    train_loss:0.0161    val_loss:0.005    y_val:0.311    y_val_pred:0.293
# i:8    j:35    train_loss:0.0092    val_loss:0.006    y_val:0.477    y_val_pred:0.399
# i:8    j:36    train_loss:0.0010    val_loss:0.012    y_val:0.051    y_val_pred:0.197
# i:8    j:37    train_loss:0.0127    val_loss:0.008    y_val:0.304    y_val_pred:0.130
# i:8    j:38    train_loss:0.0019    val_loss:0.006    y_val:0.998    y_val_pred:0.782
# i:8    j:39    train_loss:0.0018    val_loss:0.008    y_val:0.015    y_val_pred:0.071
# i:8    j:40    train_loss:0.0030    val_loss:0.008    y_val:0.424    y_val_pred:0.463
# i:8    j:41    train_loss:0.0021    val_loss:0.008    y_val:0.199    y_val_pred:0.349
# i:8    j:42    train_loss:0.0112    val_loss:0.010    y_val:0.266    y_val_pred:0.317
# i:8    j:43    train_loss:0.0046    val_loss:0.007    y_val:0.199    y_val_pred:0.319
# i:8    j:44    train_loss:0.0261    val_loss:0.008    y_val:0.304    y_val_pred:0.254
# i:8    j:45    train_loss:0.0073    val_loss:0.007    y_val:0.019    y_val_pred:0.043
# i:8    j:46    train_loss:0.0041    val_loss:0.012    y_val:0.266    y_val_pred:0.266
# i:8    j:47    train_loss:0.0025    val_loss:0.006    y_val:0.304    y_val_pred:0.284
# i:8    j:48    train_loss:0.0042    val_loss:0.009    y_val:0.454    y_val_pred:0.585
# i:8    j:49    train_loss:0.0036    val_loss:0.008    y_val:0.270    y_val_pred:0.383
# i:8    j:50    train_loss:0.0036    val_loss:0.008    y_val:0.066    y_val_pred:0.126
# i:8    j:51    train_loss:0.0008    val_loss:0.007    y_val:0.955    y_val_pred:0.972
# i:8    j:52    train_loss:0.0005    val_loss:0.008    y_val:0.066    y_val_pred:0.120
# train model saved
# i:8    j:53    train_loss:0.0029    val_loss:0.009    y_val:0.023    y_val_pred:0.210
# i:9    j:0    train_loss:0.0032    val_loss:0.009    y_val:0.424    y_val_pred:0.491
# i:9    j:1    train_loss:0.0054    val_loss:0.007    y_val:0.816    y_val_pred:0.886
# i:9    j:2    train_loss:0.0125    val_loss:0.009    y_val:0.805    y_val_pred:0.872
# i:9    j:3    train_loss:0.0021    val_loss:0.007    y_val:0.051    y_val_pred:0.137
# i:9    j:4    train_loss:0.0051    val_loss:0.008    y_val:0.424    y_val_pred:0.563
# i:9    j:5    train_loss:0.0041    val_loss:0.006    y_val:0.280    y_val_pred:0.256
# i:9    j:6    train_loss:0.0225    val_loss:0.008    y_val:0.051    y_val_pred:0.077
# i:9    j:7    train_loss:0.0026    val_loss:0.008    y_val:0.023    y_val_pred:0.281
# i:9    j:8    train_loss:0.0109    val_loss:0.007    y_val:0.028    y_val_pred:0.042
# i:9    j:9    train_loss:0.0034    val_loss:0.005    y_val:0.998    y_val_pred:0.957
# i:9    j:10    train_loss:0.0369    val_loss:0.006    y_val:0.323    y_val_pred:0.223
# i:9    j:11    train_loss:0.0030    val_loss:0.008    y_val:0.019    y_val_pred:0.124
# i:9    j:12    train_loss:0.0028    val_loss:0.010    y_val:0.323    y_val_pred:0.250
# i:9    j:13    train_loss:0.0037    val_loss:0.011    y_val:0.011    y_val_pred:0.022
# i:9    j:14    train_loss:0.0059    val_loss:0.007    y_val:0.492    y_val_pred:0.410
# i:9    j:15    train_loss:0.0124    val_loss:0.006    y_val:0.210    y_val_pred:0.150
# i:9    j:16    train_loss:0.0025    val_loss:0.005    y_val:0.962    y_val_pred:0.906
# i:9    j:17    train_loss:0.0011    val_loss:0.006    y_val:0.955    y_val_pred:0.878
# i:9    j:18    train_loss:0.0018    val_loss:0.006    y_val:0.280    y_val_pred:0.268
# i:9    j:19    train_loss:0.0054    val_loss:0.006    y_val:0.041    y_val_pred:0.054
# i:9    j:20    train_loss:0.0020    val_loss:0.007    y_val:0.051    y_val_pred:0.058
# i:9    j:21    train_loss:0.0052    val_loss:0.009    y_val:0.871    y_val_pred:0.898
# i:9    j:22    train_loss:0.0031    val_loss:0.007    y_val:0.199    y_val_pred:0.312
# i:9    j:23    train_loss:0.0009    val_loss:0.004    y_val:0.011    y_val_pred:0.068
# i:9    j:24    train_loss:0.0036    val_loss:0.005    y_val:0.805    y_val_pred:0.881
# i:9    j:25    train_loss:0.0024    val_loss:0.006    y_val:0.801    y_val_pred:0.868
# i:9    j:26    train_loss:0.0065    val_loss:0.007    y_val:0.805    y_val_pred:0.880
# i:9    j:27    train_loss:0.0146    val_loss:0.006    y_val:0.323    y_val_pred:0.316
# i:9    j:28    train_loss:0.0051    val_loss:0.008    y_val:0.955    y_val_pred:0.859
# i:9    j:29    train_loss:0.0160    val_loss:0.009    y_val:0.801    y_val_pred:0.777
# i:9    j:30    train_loss:0.0026    val_loss:0.008    y_val:0.028    y_val_pred:0.047
# i:9    j:31    train_loss:0.0023    val_loss:0.004    y_val:0.304    y_val_pred:0.253
# i:9    j:32    train_loss:0.0025    val_loss:0.006    y_val:0.028    y_val_pred:0.086
# i:9    j:33    train_loss:0.0020    val_loss:0.004    y_val:0.041    y_val_pred:0.067
# test model saved
# i:9    j:34    train_loss:0.0039    val_loss:0.007    y_val:0.270    y_val_pred:0.327
# i:9    j:35    train_loss:0.0019    val_loss:0.004    y_val:0.477    y_val_pred:0.421
# i:9    j:36    train_loss:0.0007    val_loss:0.007    y_val:0.467    y_val_pred:0.522
# i:9    j:37    train_loss:0.0027    val_loss:0.004    y_val:0.066    y_val_pred:0.102
# i:9    j:38    train_loss:0.0027    val_loss:0.005    y_val:0.424    y_val_pred:0.377
# i:9    j:39    train_loss:0.0014    val_loss:0.005    y_val:0.015    y_val_pred:0.033
# i:9    j:40    train_loss:0.0019    val_loss:0.006    y_val:0.311    y_val_pred:0.247
# i:9    j:41    train_loss:0.0065    val_loss:0.007    y_val:0.323    y_val_pred:0.296
# i:9    j:42    train_loss:0.0073    val_loss:0.005    y_val:0.266    y_val_pred:0.234
# i:9    j:43    train_loss:0.0123    val_loss:0.011    y_val:0.465    y_val_pred:0.329
# i:9    j:44    train_loss:0.0023    val_loss:0.007    y_val:0.394    y_val_pred:0.352
# i:9    j:45    train_loss:0.0012    val_loss:0.007    y_val:0.199    y_val_pred:0.267
# i:9    j:46    train_loss:0.0030    val_loss:0.006    y_val:0.886    y_val_pred:0.852
# i:9    j:47    train_loss:0.0034    val_loss:0.007    y_val:0.066    y_val_pred:0.116
# i:9    j:48    train_loss:0.0036    val_loss:0.005    y_val:0.236    y_val_pred:0.215
# i:9    j:49    train_loss:0.0020    val_loss:0.005    y_val:0.066    y_val_pred:0.076
# i:9    j:50    train_loss:0.0010    val_loss:0.004    y_val:0.492    y_val_pred:0.405
# i:9    j:51    train_loss:0.0015    val_loss:0.005    y_val:0.304    y_val_pred:0.132
# i:9    j:52    train_loss:0.0026    val_loss:0.005    y_val:0.304    y_val_pred:0.281
# i:9    j:53    train_loss:0.0024    val_loss:0.006    y_val:0.388    y_val_pred:0.388
# i:10    j:0    train_loss:0.0035    val_loss:0.008    y_val:0.285    y_val_pred:0.167
# i:10    j:1    train_loss:0.0129    val_loss:0.005    y_val:0.311    y_val_pred:0.232
# i:10    j:2    train_loss:0.0044    val_loss:0.005    y_val:0.270    y_val_pred:0.193
# i:10    j:3    train_loss:0.0031    val_loss:0.007    y_val:0.304    y_val_pred:0.186
# i:10    j:4    train_loss:0.0019    val_loss:0.005    y_val:0.323    y_val_pred:0.234
# i:10    j:5    train_loss:0.0050    val_loss:0.006    y_val:0.428    y_val_pred:0.452
# i:10    j:6    train_loss:0.0018    val_loss:0.004    y_val:0.293    y_val_pred:0.350
# i:10    j:7    train_loss:0.0008    val_loss:0.006    y_val:0.199    y_val_pred:0.280
# i:10    j:8    train_loss:0.0043    val_loss:0.005    y_val:0.019    y_val_pred:0.077
# i:10    j:9    train_loss:0.0023    val_loss:0.007    y_val:0.323    y_val_pred:0.239
# i:10    j:10    train_loss:0.0024    val_loss:0.005    y_val:0.064    y_val_pred:-0.016
# ...
# i:16    j:32    train_loss:0.0028    val_loss:0.003    y_val:0.212    y_val_pred:0.240
# i:16    j:33    train_loss:0.0008    val_loss:0.005    y_val:0.311    y_val_pred:0.199
# i:16    j:34    train_loss:0.0006    val_loss:0.004    y_val:0.009    y_val_pred:0.017
# i:16    j:35    train_loss:0.0013    val_loss:0.005    y_val:0.482    y_val_pred:0.397
# i:16    j:36    train_loss:0.0018    val_loss:0.005    y_val:0.323    y_val_pred:0.223
# i:16    j:37    train_loss:0.0016    val_loss:0.005    y_val:0.801    y_val_pred:0.938
# i:16    j:38    train_loss:0.0006    val_loss:0.004    y_val:0.066    y_val_pred:0.048
# i:16    j:39    train_loss:0.0013    val_loss:0.004    y_val:0.030    y_val_pred:0.079
# i:16    j:40    train_loss:0.0024    val_loss:0.004    y_val:0.199    y_val_pred:0.258
# i:16    j:41    train_loss:0.0011    val_loss:0.004    y_val:0.019    y_val_pred:0.043
# i:16    j:42    train_loss:0.0020    val_loss:0.004    y_val:0.959    y_val_pred:0.791
# i:16    j:43    train_loss:0.0009    val_loss:0.003    y_val:0.199    y_val_pred:0.287
# i:16    j:44    train_loss:0.0011    val_loss:0.005    y_val:0.293    y_val_pred:0.255
# i:16    j:45    train_loss:0.0015    val_loss:0.005    y_val:0.388    y_val_pred:0.411
# i:16    j:46    train_loss:0.0013    val_loss:0.005    y_val:0.955    y_val_pred:0.840
# i:16    j:47    train_loss:0.0028    val_loss:0.004    y_val:0.962    y_val_pred:0.851
# i:16    j:48    train_loss:0.0020    val_loss:0.004    y_val:0.452    y_val_pred:0.406
# i:16    j:49    train_loss:0.0009    val_loss:0.004    y_val:0.015    y_val_pred:0.087
# i:16    j:50    train_loss:0.0248    val_loss:0.004    y_val:0.871    y_val_pred:0.915
# i:16    j:51    train_loss:0.0014    val_loss:0.004    y_val:0.492    y_val_pred:0.547
# i:16    j:52    train_loss:0.0010    val_loss:0.006    y_val:0.028    y_val_pred:0.048
# i:16    j:53    train_loss:0.0029    val_loss:0.005    y_val:0.323    y_val_pred:0.319
# i:17    j:0    train_loss:0.0032    val_loss:0.005    y_val:0.311    y_val_pred:0.190
# i:17    j:1    train_loss:0.0023    val_loss:0.005    y_val:0.015    y_val_pred:0.026
# i:17    j:2    train_loss:0.0021    val_loss:0.004    y_val:0.388    y_val_pred:0.450
# i:17    j:3    train_loss:0.0011    val_loss:0.005    y_val:0.422    y_val_pred:0.483
# i:17    j:4    train_loss:0.0011    val_loss:0.005    y_val:0.064    y_val_pred:0.075
# i:17    j:5    train_loss:0.0015    val_loss:0.005    y_val:0.028    y_val_pred:0.067
# i:17    j:6    train_loss:0.0019    val_loss:0.005    y_val:0.805    y_val_pred:0.949
# i:17    j:7    train_loss:0.0113    val_loss:0.005    y_val:0.051    y_val_pred:0.046
# i:17    j:8    train_loss:0.0017    val_loss:0.004    y_val:0.424    y_val_pred:0.444
# i:17    j:9    train_loss:0.0021    val_loss:0.004    y_val:0.011    y_val_pred:0.092
# i:17    j:10    train_loss:0.0008    val_loss:0.004    y_val:0.998    y_val_pred:0.868
# i:17    j:11    train_loss:0.0013    val_loss:0.005    y_val:0.998    y_val_pred:0.855
# i:17    j:12    train_loss:0.0020    val_loss:0.004    y_val:0.311    y_val_pred:0.198
# i:17    j:13    train_loss:0.0016    val_loss:0.006    y_val:0.270    y_val_pred:0.202
# i:17    j:14    train_loss:0.0011    val_loss:0.004    y_val:0.210    y_val_pred:0.256
# i:17    j:15    train_loss:0.0029    val_loss:0.004    y_val:0.304    y_val_pred:0.209
# i:17    j:16    train_loss:0.0018    val_loss:0.005    y_val:0.482    y_val_pred:0.466
# i:17    j:17    train_loss:0.0020    val_loss:0.005    y_val:0.270    y_val_pred:0.201
# i:17    j:18    train_loss:0.0006    val_loss:0.004    y_val:0.426    y_val_pred:0.425
# i:17    j:19    train_loss:0.0007    val_loss:0.006    y_val:0.015    y_val_pred:0.017
# i:17    j:20    train_loss:0.0011    val_loss:0.005    y_val:0.011    y_val_pred:-0.010
# i:17    j:21    train_loss:0.0057    val_loss:0.005    y_val:0.394    y_val_pred:0.324
# i:17    j:22    train_loss:0.0022    val_loss:0.006    y_val:0.477    y_val_pred:0.386
# i:17    j:23    train_loss:0.0007    val_loss:0.005    y_val:0.030    y_val_pred:0.056
# i:17    j:24    train_loss:0.0045    val_loss:0.004    y_val:0.467    y_val_pred:0.457
# i:17    j:25    train_loss:0.0008    val_loss:0.005    y_val:0.285    y_val_pred:0.295
# i:17    j:26    train_loss:0.0006    val_loss:0.005    y_val:0.030    y_val_pred:0.063
# i:17    j:27    train_loss:0.0007    val_loss:0.005    y_val:0.015    y_val_pred:0.014
# i:17    j:28    train_loss:0.0006    val_loss:0.004    y_val:0.011    y_val_pred:0.068
# i:17    j:29    train_loss:0.0026    val_loss:0.007    y_val:0.030    y_val_pred:0.072
# i:17    j:30    train_loss:0.0014    val_loss:0.005    y_val:0.482    y_val_pred:0.421
# i:17    j:31    train_loss:0.0005    val_loss:0.005    y_val:0.293    y_val_pred:0.369
# i:17    j:32    train_loss:0.0021    val_loss:0.006    y_val:0.477    y_val_pred:0.409
# i:17    j:33    train_loss:0.0019    val_loss:0.005    y_val:0.422    y_val_pred:0.537
# i:17    j:34    train_loss:0.0009    val_loss:0.004    y_val:0.210    y_val_pred:0.337
# i:17    j:35    train_loss:0.0013    val_loss:0.005    y_val:0.394    y_val_pred:0.434
# i:17    j:36    train_loss:0.0023    val_loss:0.004    y_val:0.871    y_val_pred:0.886
# i:17    j:37    train_loss:0.0047    val_loss:0.005    y_val:0.959    y_val_pred:0.883
# i:17    j:38    train_loss:0.0013    val_loss:0.005    y_val:0.424    y_val_pred:0.392
# i:17    j:39    train_loss:0.0016    val_loss:0.005    y_val:0.424    y_val_pred:0.430
# i:17    j:40    train_loss:0.0014    val_loss:0.005    y_val:0.023    y_val_pred:0.133
# i:17    j:41    train_loss:0.0006    val_loss:0.008    y_val:0.236    y_val_pred:0.201
# i:17    j:42    train_loss:0.0012    val_loss:0.005    y_val:0.452    y_val_pred:0.411
# i:17    j:43    train_loss:0.0011    val_loss:0.006    y_val:0.293    y_val_pred:0.249
# i:17    j:44    train_loss:0.0004    val_loss:0.005    y_val:0.236    y_val_pred:0.193
# i:17    j:45    train_loss:0.0036    val_loss:0.005    y_val:0.426    y_val_pred:0.389
# i:17    j:46    train_loss:0.0015    val_loss:0.005    y_val:0.210    y_val_pred:0.234
# i:17    j:47    train_loss:0.0018    val_loss:0.004    y_val:0.886    y_val_pred:0.806
# i:17    j:48    train_loss:0.0006    val_loss:0.005    y_val:0.323    y_val_pred:0.259
# i:17    j:49    train_loss:0.0021    val_loss:0.004    y_val:0.293    y_val_pred:0.195
# i:17    j:50    train_loss:0.0020    val_loss:0.005    y_val:0.064    y_val_pred:0.034
# i:17    j:51    train_loss:0.0021    val_loss:0.004    y_val:0.293    y_val_pred:0.206
# i:17    j:52    train_loss:0.0013    val_loss:0.005    y_val:0.212    y_val_pred:0.257
# i:17    j:53    train_loss:0.0017    val_loss:0.004    y_val:0.051    y_val_pred:0.044
# i:18    j:0    train_loss:0.0018    val_loss:0.003    y_val:0.936    y_val_pred:0.865
# i:18    j:1    train_loss:0.0024    val_loss:0.004    y_val:0.266    y_val_pred:0.265
# i:18    j:2    train_loss:0.0011    val_loss:0.005    y_val:0.388    y_val_pred:0.389
# i:18    j:3    train_loss:0.0025    val_loss:0.004    y_val:0.428    y_val_pred:0.439
# i:18    j:4    train_loss:0.0013    val_loss:0.004    y_val:0.492    y_val_pred:0.529
# i:18    j:5    train_loss:0.0021    val_loss:0.005    y_val:0.998    y_val_pred:0.941
# i:18    j:6    train_loss:0.0015    val_loss:0.005    y_val:0.962    y_val_pred:0.945
# i:18    j:7    train_loss:0.0040    val_loss:0.005    y_val:0.285    y_val_pred:0.233
# i:18    j:8    train_loss:0.0013    val_loss:0.004    y_val:0.030    y_val_pred:0.092
# i:18    j:9    train_loss:0.0006    val_loss:0.004    y_val:0.019    y_val_pred:0.100
# i:18    j:10    train_loss:0.0009    val_loss:0.005    y_val:0.871    y_val_pred:0.894
# i:18    j:11    train_loss:0.0007    val_loss:0.004    y_val:0.492    y_val_pred:0.464
# i:18    j:12    train_loss:0.0060    val_loss:0.004    y_val:0.280    y_val_pred:0.289
# i:18    j:13    train_loss:0.0010    val_loss:0.005    y_val:0.936    y_val_pred:0.924
# i:18    j:14    train_loss:0.0008    val_loss:0.003    y_val:0.293    y_val_pred:0.250
# i:18    j:15    train_loss:0.0025    val_loss:0.004    y_val:0.030    y_val_pred:0.129
# i:18    j:16    train_loss:0.0008    val_loss:0.003    y_val:0.066    y_val_pred:0.051
# i:18    j:17    train_loss:0.0020    val_loss:0.004    y_val:0.477    y_val_pred:0.435
# i:18    j:18    train_loss:0.0009    val_loss:0.004    y_val:0.454    y_val_pred:0.533
# i:18    j:19    train_loss:0.0032    val_loss:0.004    y_val:0.394    y_val_pred:0.457
# i:18    j:20    train_loss:0.0026    val_loss:0.003    y_val:0.019    y_val_pred:0.054
# i:18    j:21    train_loss:0.0011    val_loss:0.004    y_val:0.328    y_val_pred:0.304
# i:18    j:22    train_loss:0.0011    val_loss:0.004    y_val:0.311    y_val_pred:0.227
# i:18    j:23    train_loss:0.0008    val_loss:0.004    y_val:0.454    y_val_pred:0.463
# i:18    j:24    train_loss:0.0016    val_loss:0.004    y_val:0.028    y_val_pred:0.090
# i:18    j:25    train_loss:0.0009    val_loss:0.004    y_val:0.030    y_val_pred:0.077
# i:18    j:26    train_loss:0.0008    val_loss:0.004    y_val:0.041    y_val_pred:0.050
# i:18    j:27    train_loss:0.0007    val_loss:0.004    y_val:0.816    y_val_pred:0.853
# i:18    j:28    train_loss:0.0020    val_loss:0.004    y_val:0.467    y_val_pred:0.440
# i:18    j:29    train_loss:0.0012    val_loss:0.004    y_val:0.886    y_val_pred:0.914
# i:18    j:30    train_loss:0.0025    val_loss:0.005    y_val:0.886    y_val_pred:0.902
# i:18    j:31    train_loss:0.0025    val_loss:0.005    y_val:0.212    y_val_pred:0.239
# i:18    j:32    train_loss:0.0008    val_loss:0.005    y_val:0.199    y_val_pred:0.236
# i:18    j:33    train_loss:0.0229    val_loss:0.005    y_val:0.210    y_val_pred:0.313
# i:18    j:34    train_loss:0.0015    val_loss:0.004    y_val:0.199    y_val_pred:0.253
# i:18    j:35    train_loss:0.0045    val_loss:0.004    y_val:0.805    y_val_pred:0.902
# i:18    j:36    train_loss:0.0004    val_loss:0.005    y_val:0.805    y_val_pred:0.893
# i:18    j:37    train_loss:0.0013    val_loss:0.005    y_val:0.424    y_val_pred:0.407
# i:18    j:38    train_loss:0.0011    val_loss:0.005    y_val:0.805    y_val_pred:0.838
# i:18    j:39    train_loss:0.0039    val_loss:0.006    y_val:0.270    y_val_pred:0.358
# i:18    j:40    train_loss:0.0009    val_loss:0.005    y_val:0.452    y_val_pred:0.392
# i:18    j:41    train_loss:0.0008    val_loss:0.005    y_val:0.064    y_val_pred:0.035
# i:18    j:42    train_loss:0.0022    val_loss:0.005    y_val:0.266    y_val_pred:0.267
# i:18    j:43    train_loss:0.0015    val_loss:0.004    y_val:0.477    y_val_pred:0.469
# i:18    j:44    train_loss:0.0015    val_loss:0.004    y_val:0.019    y_val_pred:0.080
# i:18    j:45    train_loss:0.0025    val_loss:0.004    y_val:0.805    y_val_pred:0.907
# i:18    j:46    train_loss:0.0016    val_loss:0.003    y_val:0.015    y_val_pred:0.046
# i:18    j:47    train_loss:0.0010    val_loss:0.004    y_val:0.422    y_val_pred:0.447
# i:18    j:48    train_loss:0.0017    val_loss:0.004    y_val:0.955    y_val_pred:0.900
# i:18    j:49    train_loss:0.0022    val_loss:0.005    y_val:0.064    y_val_pred:0.136
# i:18    j:50    train_loss:0.0017    val_loss:0.006    y_val:0.886    y_val_pred:0.925
# i:18    j:51    train_loss:0.0015    val_loss:0.005    y_val:0.452    y_val_pred:0.334
# i:18    j:52    train_loss:0.0007    val_loss:0.004    y_val:0.028    y_val_pred:0.048
# i:18    j:53    train_loss:0.0030    val_loss:0.005    y_val:0.477    y_val_pred:0.375
# i:19    j:0    train_loss:0.0006    val_loss:0.005    y_val:0.477    y_val_pred:0.412
# i:19    j:1    train_loss:0.0011    val_loss:0.005    y_val:0.424    y_val_pred:0.401
# i:19    j:2    train_loss:0.0017    val_loss:0.004    y_val:0.015    y_val_pred:0.026
# i:19    j:3    train_loss:0.0015    val_loss:0.005    y_val:0.030    y_val_pred:0.084
# i:19    j:4    train_loss:0.0023    val_loss:0.006    y_val:0.477    y_val_pred:0.427
# i:19    j:5    train_loss:0.0006    val_loss:0.004    y_val:0.394    y_val_pred:0.332
# i:19    j:6    train_loss:0.0031    val_loss:0.005    y_val:0.998    y_val_pred:0.852
# i:19    j:7    train_loss:0.0184    val_loss:0.004    y_val:0.805    y_val_pred:0.841
# i:19    j:8    train_loss:0.0098    val_loss:0.004    y_val:0.801    y_val_pred:0.893
# i:19    j:9    train_loss:0.0019    val_loss:0.006    y_val:0.886    y_val_pred:0.872
# i:19    j:10    train_loss:0.0026    val_loss:0.005    y_val:0.236    y_val_pred:0.339
# i:19    j:11    train_loss:0.0006    val_loss:0.005    y_val:0.871    y_val_pred:0.965
# i:19    j:12    train_loss:0.0014    val_loss:0.005    y_val:0.936    y_val_pred:0.959
# i:19    j:13    train_loss:0.0017    val_loss:0.006    y_val:0.424    y_val_pred:0.530
# i:19    j:14    train_loss:0.0014    val_loss:0.006    y_val:0.285    y_val_pred:0.335
# i:19    j:15    train_loss:0.0019    val_loss:0.009    y_val:0.424    y_val_pred:0.458
# i:19    j:16    train_loss:0.0024    val_loss:0.005    y_val:0.270    y_val_pred:0.237
# i:19    j:17    train_loss:0.0022    val_loss:0.004    y_val:0.236    y_val_pred:0.251
# i:19    j:18    train_loss:0.0023    val_loss:0.006    y_val:0.816    y_val_pred:0.960
# i:19    j:19    train_loss:0.0035    val_loss:0.004    y_val:0.212    y_val_pred:0.270
# i:19    j:20    train_loss:0.0063    val_loss:0.007    y_val:0.266    y_val_pred:0.349
# i:19    j:21    train_loss:0.0020    val_loss:0.006    y_val:0.959    y_val_pred:0.882
# i:19    j:22    train_loss:0.0023    val_loss:0.006    y_val:0.424    y_val_pred:0.442
# i:19    j:23    train_loss:0.0034    val_loss:0.005    y_val:0.424    y_val_pred:0.376
# i:19    j:24    train_loss:0.0011    val_loss:0.005    y_val:0.266    y_val_pred:0.273
# i:19    j:25    train_loss:0.0007    val_loss:0.006    y_val:0.270    y_val_pred:0.274
# i:19    j:26    train_loss:0.0052    val_loss:0.006    y_val:0.955    y_val_pred:0.848
# i:19    j:27    train_loss:0.0012    val_loss:0.004    y_val:0.962    y_val_pred:0.901
# i:19    j:28    train_loss:0.0013    val_loss:0.005    y_val:0.293    y_val_pred:0.198
# i:19    j:29    train_loss:0.0023    val_loss:0.005    y_val:0.009    y_val_pred:0.045
# i:19    j:30    train_loss:0.0060    val_loss:0.005    y_val:0.422    y_val_pred:0.467
# i:19    j:31    train_loss:0.0005    val_loss:0.005    y_val:0.028    y_val_pred:-0.010
# i:19    j:32    train_loss:0.0012    val_loss:0.006    y_val:0.015    y_val_pred:-0.011
# i:19    j:33    train_loss:0.0013    val_loss:0.004    y_val:0.023    y_val_pred:0.087
# i:19    j:34    train_loss:0.0032    val_loss:0.004    y_val:0.266    y_val_pred:0.295
# i:19    j:35    train_loss:0.0012    val_loss:0.004    y_val:0.028    y_val_pred:0.059
# i:19    j:36    train_loss:0.0028    val_loss:0.005    y_val:0.266    y_val_pred:0.194
# i:19    j:37    train_loss:0.0011    val_loss:0.004    y_val:0.236    y_val_pred:0.264
# i:19    j:38    train_loss:0.0016    val_loss:0.004    y_val:0.023    y_val_pred:0.139
# i:19    j:39    train_loss:0.0015    val_loss:0.005    y_val:0.011    y_val_pred:0.119
# i:19    j:40    train_loss:0.0006    val_loss:0.004    y_val:0.962    y_val_pred:0.920
# i:19    j:41    train_loss:0.0010    val_loss:0.004    y_val:0.302    y_val_pred:0.268
# i:19    j:42    train_loss:0.0017    val_loss:0.005    y_val:0.199    y_val_pred:0.291
# i:19    j:43    train_loss:0.0005    val_loss:0.004    y_val:0.454    y_val_pred:0.487
# i:19    j:44    train_loss:0.0026    val_loss:0.005    y_val:0.936    y_val_pred:0.943
# i:19    j:45    train_loss:0.0017    val_loss:0.005    y_val:0.280    y_val_pred:0.251
# i:19    j:46    train_loss:0.0021    val_loss:0.004    y_val:0.323    y_val_pred:0.278
# i:19    j:47    train_loss:0.0006    val_loss:0.006    y_val:0.210    y_val_pred:0.420
# i:19    j:48    train_loss:0.0016    val_loss:0.004    y_val:0.424    y_val_pred:0.414
# i:19    j:49    train_loss:0.0018    val_loss:0.005    y_val:0.871    y_val_pred:0.876
# i:19    j:50    train_loss:0.0007    val_loss:0.005    y_val:0.936    y_val_pred:0.943
# i:19    j:51    train_loss:0.0019    val_loss:0.005    y_val:0.452    y_val_pred:0.437
# i:19    j:52    train_loss:0.0006    val_loss:0.005    y_val:0.266    y_val_pred:0.359
# i:19    j:53    train_loss:0.0032    val_loss:0.005    y_val:0.011    y_val_pred:0.147
# last model saved

# %% [markdown]
# #7. 훈련 결과 플롯

# %%
def get_pred(model, dataloader:DataLoader, pretrained:str = None)-> list:

    device = "cuda" if torch.cuda.is_available() else "cpu"
    # device = "cpu"

    if pretrained != None:
        model.load_state_dict(torch.load(pretrained, "cuda"))
    model = nn.DataParallel(model)
    model.to(device)

    y_lst = []
    y_pred_lst = []

    for i,j in dataloader:
        j = j.tolist()
        y_lst.extend(j)
        y_pred = model(i.to(device).to(torch.float32))
        y_pred = y_pred.squeeze(1).to("cpu").tolist()
        y_pred_lst.extend(y_pred)

    return y_lst, y_pred_lst

def denormalize(lst:list) -> list:
    s_props = stack_props("TS", props)
    n_min = min(s_props)
    n_max = max(s_props)

    res = []
    for i in lst:
        res.append((n_max-n_min)*i + n_min)
    return res

def get_rmse(x:list,y:list) -> float:
    rmse = np.array(x)- np.array(y)
    rmse = np.square(rmse).sum()/len(x)
    rmse = np.power(rmse,0.5)
    return rmse

# %%
y_lst, y_pred_lst = get_pred(my_model, train_loader, "./models/test_best_model.pth")
y_lst = denormalize(y_lst)
y_pred_lst = denormalize(y_pred_lst)
plt.scatter(y_lst, y_pred_lst, label = "train")
print(f"train_rsme:{get_rmse(y_lst,y_pred_lst)}")

y_lst, y_pred_lst = get_pred(my_model, test_loader, "./models/test_best_model.pth")
y_lst = denormalize(y_lst)
y_pred_lst = denormalize(y_pred_lst)
plt.scatter(y_lst, y_pred_lst, label = "test")
print(f"test_rsme:{get_rmse(y_lst,y_pred_lst)}")

plt.legend()
# Out:
# train_rsme:83.17993414682275
# test_rsme:78.71001356974566
